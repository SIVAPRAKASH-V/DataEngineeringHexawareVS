# %% [markdown]
# # Databricks Day02 - `Sivaprakash V`

# %% [markdown]
# ## Initiate session

# %%
# initialize the session
from pyspark import SparkContext
from pyspark.sql import SparkSession

sc = SparkContext.getOrCreate()
spark = SparkSession.builder.appName('Databricks first program').getOrCreate()

# %% [markdown]
# ## Write Data to CSV, JSON, Parquet

# %% [markdown]
# ### sample data

# %%
# Create a sample DataFrame
data = [
    (1, "Alice", 34, "NY", 5000.50),
    (2, "Bob", 45, "CA", 7000.75),
    (3, "Charlie", 29, "TX", 4000.10),
    (4, "Diana", 39, "WA", 6500.80),
]

columns = ["ID", "Name", "Age", "State", "Salary"]

df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +---+-------+---+-----+-------+
# | ID|   Name|Age|State| Salary|
# +---+-------+---+-----+-------+
# |  1|  Alice| 34|   NY| 5000.5|
# |  2|    Bob| 45|   CA|7000.75|
# |  3|Charlie| 29|   TX| 4000.1|
# |  4|  Diana| 39|   WA| 6500.8|
# +---+-------+---+-----+-------+

# %% [markdown]
# ### writing to CSV

# %%
csv_path = "dbfs:/user/hive/warehouse/employee_csv"

df.write.format("csv").option("header", "true").mode("overwrite").save(csv_path)

# %% [markdown]
# ### writing to JSON

# %%
json_path = "dbfs:/user/hive/warehouse/employee_json"

df.write.format("json").mode("overwrite").save(json_path)

# %% [markdown]
# ### writing to parquet file

# %%
parquet_path = "dbfs:/user/hive/warehouse/employee_parquet"

df.write.format("parquet").mode("overwrite").save(parquet_path)

# %% [markdown]
# ### writing to delta

# %%
delta_path = "dbfs:/user/hive/warehouse/employee_delta"

df.write.format("delta").mode("overwrite").save(delta_path)

# %% [markdown]
# ### writing to table

# %%
df.write.format('delta').saveAsTable("mydata_delta", mode='overwrite')

# %% [markdown]
# ### Reading the written data

# %%
# %sql
select * from mydata_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Age</th><th>State</th><th>Salary</th></tr></thead><tbody><tr><td>3</td><td>Charlie</td><td>29</td><td>TX</td><td>4000.1</td></tr><tr><td>1</td><td>Alice</td><td>34</td><td>NY</td><td>5000.5</td></tr><tr><td>4</td><td>Diana</td><td>39</td><td>WA</td><td>6500.8</td></tr><tr><td>2</td><td>Bob</td><td>45</td><td>CA</td><td>7000.75</td></tr></tbody></table></div>

# %%
df_csv = spark.read.format("csv").option("header", "true").load(csv_path)
df_csv.show()
# Out:
# +---+-------+---+-----+-------+
# | ID|   Name|Age|State| Salary|
# +---+-------+---+-----+-------+
# |  3|Charlie| 29|   TX| 4000.1|
# |  1|  Alice| 34|   NY| 5000.5|
# |  4|  Diana| 39|   WA| 6500.8|
# |  2|    Bob| 45|   CA|7000.75|
# +---+-------+---+-----+-------+

# %%
df_json = spark.read.format("json").load(json_path)
df_json.show()
# Out:
# +---+---+-------+-------+-----+
# |Age| ID|   Name| Salary|State|
# +---+---+-------+-------+-----+
# | 29|  3|Charlie| 4000.1|   TX|
# | 34|  1|  Alice| 5000.5|   NY|
# | 39|  4|  Diana| 6500.8|   WA|
# | 45|  2|    Bob|7000.75|   CA|
# +---+---+-------+-------+-----+

# %%
df_parquet = spark.read.format("parquet").load(parquet_path)
df_parquet.show()
# Out:
# +---+-------+---+-----+-------+
# | ID|   Name|Age|State| Salary|
# +---+-------+---+-----+-------+
# |  3|Charlie| 29|   TX| 4000.1|
# |  1|  Alice| 34|   NY| 5000.5|
# |  4|  Diana| 39|   WA| 6500.8|
# |  2|    Bob| 45|   CA|7000.75|
# +---+-------+---+-----+-------+

# %%
df_delta = spark.read.format("delta").load(delta_path)
df_delta.show()
# Out:
# +---+-------+---+-----+-------+
# | ID|   Name|Age|State| Salary|
# +---+-------+---+-----+-------+
# |  3|Charlie| 29|   TX| 4000.1|
# |  1|  Alice| 34|   NY| 5000.5|
# |  4|  Diana| 39|   WA| 6500.8|
# |  2|    Bob| 45|   CA|7000.75|
# +---+-------+---+-----+-------+

# %% [markdown]
# ## Exploratory Data Analysis on Credit card data

# %%
df = spark.read.format("delta").load("dbfs:/user/hive/warehouse/credit_card")

# %% [markdown]
# ### Data exploration

# %%
df.printSchema()
# Out:
# root
#  |-- RowNumber: long (nullable = true)
#  |-- CustomerId: long (nullable = true)
#  |-- Surname: string (nullable = true)
#  |-- CreditScore: long (nullable = true)
#  |-- Geography: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: long (nullable = true)
#  |-- Tenure: long (nullable = true)
#  |-- Balance: double (nullable = true)
#  |-- NumOfProducts: long (nullable = true)
#  |-- IsActiveMember: long (nullable = true)
#  |-- EstimatedSalary: double (nullable = true)
#  |-- Exited: long (nullable = true)

# %%
# Number of rows
num_rows3 = df.count()
# Number of columns
num_columns3 = len(df.columns)
print(f"Number of rows: {num_rows3}")
print(f"Number of columns: {num_columns3}")
# Out:
# Number of rows: 10000
# Number of columns: 13

# %%
from pyspark.sql.functions import col, sum, when, lit
# Calculate null counts
null_counts2 = df.select(
    [sum(when(col(c).isNull(), 1).otherwise(0)).alias(c) for c in df.columns]
)
null_counts_dict2 = null_counts2.collect()[0].asDict()
transposed_null_counts2 = spark.createDataFrame(
    [(key, value) for key, value in null_counts_dict2.items()],
    schema=["Column", "Null Count"]
)
# Show the transposed DataFrame
transposed_null_counts2.show()
# Out:
# +---------------+----------+
# |         Column|Null Count|
# +---------------+----------+
# |      RowNumber|         0|
# |     CustomerId|         0|
# |        Surname|         0|
# |    CreditScore|         0|
# |      Geography|         0|
# |         Gender|         0|
# |            Age|         0|
# |         Tenure|         0|
# |        Balance|         0|
# |  NumOfProducts|         0|
# | IsActiveMember|         0|
# |EstimatedSalary|         0|
# |         Exited|         0|
# +---------------+----------+

# %%
# %sql
SELECT Geography, COUNT(*) AS CustomerCount
FROM credit_card
GROUP BY Geography;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Geography</th><th>CustomerCount</th></tr></thead><tbody><tr><td>Germany</td><td>2509</td></tr><tr><td>France</td><td>5014</td></tr><tr><td>Spain</td><td>2477</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %%
spark.sql("SELECT Geography, Gender, AVG(CreditScore) AS AvgCreditScore, COUNT(*) AS CustomerCount FROM credit_card GROUP BY Geography, Gender").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Geography</th><th>Gender</th><th>AvgCreditScore</th><th>CustomerCount</th></tr></thead><tbody><tr><td>Germany</td><td>Female</td><td>653.0938809723386</td><td>1193</td></tr><tr><td>France</td><td>Male</td><td>650.0646567381038</td><td>2753</td></tr><tr><td>France</td><td>Female</td><td>649.1857585139319</td><td>2261</td></tr><tr><td>Spain</td><td>Male</td><td>650.9920749279539</td><td>1388</td></tr><tr><td>Germany</td><td>Male</td><td>649.9665653495441</td><td>1316</td></tr><tr><td>Spain</td><td>Female</td><td>651.7695133149679</td><td>1089</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
SELECT Age, Balance
FROM credit_card;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Age</th><th>Balance</th></tr></thead><tbody><tr><td>42</td><td>0.0</td></tr><tr><td>41</td><td>83807.86</td></tr><tr><td>42</td><td>159660.8</td></tr><tr><td>39</td><td>0.0</td></tr><tr><td>43</td><td>125510.82</td></tr><tr><td>44</td><td>113755.78</td></tr><tr><td>50</td><td>0.0</td></tr><tr><td>29</td><td>115046.74</td></tr><tr><td>44</td><td>142051.07</td></tr><tr><td>27</td><td>134603.88</td></tr><tr><td>31</td><td>102016.72</td></tr><tr><td>24</td><td>0.0</td></tr><tr><td>34</td><td>0.0</td></tr><tr><td>25</td><td>0.0</td></tr><tr><td>35</td><td>0.0</td></tr><tr><td>45</td><td>143129.41</td></tr><tr><td>58</td><td>132602.88</td></tr><tr><td>24</td><td>0.0</td></tr><tr><td>45</td><td>0.0</td></tr><tr><td>24</td><td>0.0</td></tr><tr><td>41</td><td>0.0</td></tr><tr><td>32</td><td>0.0</td></tr><tr><td>38</td><td>0.0</td></tr><tr><td>46</td><td>0.0</td></tr><tr><td>38</td><td>0.0</td></tr><tr><td>25</td><td>0.0</td></tr><tr><td>36</td><td>136815.64</td></tr><tr><td>44</td><td>0.0</td></tr><tr><td>43</td><td>141349.43</td></tr><tr><td>29</td><td>59697.17</td></tr><tr><td>39</td><td>0.0</td></tr><tr><td>36</td><td>85311.7</td></tr><tr><td>41</td><td>110112.54</td></tr><tr><td>42</td><td>0.0</td></tr><tr><td>29</td><td>0.0</td></tr><tr><td>45</td><td>134264.04</td></tr><tr><td>31</td><td>145260.23</td></tr><tr><td>33</td><td>76548.6</td></tr><tr><td>36</td><td>0.0</td></tr><tr><td>41</td><td>70349.48</td></tr><tr><td>40</td><td>0.0</td></tr><tr><td>51</td><td>122522.32</td></tr><tr><td>61</td><td>117419.35</td></tr><tr><td>49</td><td>131394.56</td></tr><tr><td>61</td><td>155931.11</td></tr><tr><td>32</td><td>109421.13</td></tr><tr><td>27</td><td>112045.67</td></tr><tr><td>39</td><td>137843.8</td></tr><tr><td>38</td><td>103391.38</td></tr><tr><td>37</td><td>103769.22</td></tr><tr><td>44</td><td>116363.37</td></tr><tr><td>36</td><td>146050.97</td></tr><tr><td>33</td><td>0.0</td></tr><tr><td>41</td><td>125561.97</td></tr><tr><td>42</td><td>98495.72</td></tr><tr><td>43</td><td>125211.92</td></tr><tr><td>45</td><td>127864.4</td></tr><tr><td>19</td><td>75888.2</td></tr><tr><td>66</td><td>0.0</td></tr><tr><td>51</td><td>40685.92</td></tr><tr><td>35</td><td>136857.0</td></tr><tr><td>27</td><td>152328.88</td></tr><tr><td>33</td><td>56084.69</td></tr><tr><td>56</td><td>78707.16</td></tr><tr><td>26</td><td>109166.37</td></tr><tr><td>36</td><td>169831.46</td></tr><tr><td>34</td><td>101633.04</td></tr><tr><td>43</td><td>123180.01</td></tr><tr><td>35</td><td>150725.53</td></tr><tr><td>21</td><td>98373.26</td></tr><tr><td>58</td><td>133745.44</td></tr><tr><td>29</td><td>0.0</td></tr><tr><td>37</td><td>163607.18</td></tr><tr><td>25</td><td>157780.84</td></tr><tr><td>36</td><td>0.0</td></tr><tr><td>21</td><td>178718.19</td></tr><tr><td>55</td><td>0.0</td></tr><tr><td>32</td><td>0.0</td></tr><tr><td>33</td><td>77253.22</td></tr><tr><td>41</td><td>122189.66</td></tr><tr><td>34</td><td>96645.54</td></tr><tr><td>32</td><td>0.0</td></tr><tr><td>36</td><td>0.0</td></tr><tr><td>34</td><td>90307.62</td></tr><tr><td>46</td><td>0.0</td></tr><tr><td>75</td><td>0.0</td></tr><tr><td>22</td><td>121681.82</td></tr><tr><td>30</td><td>0.0</td></tr><tr><td>46</td><td>0.0</td></tr><tr><td>28</td><td>81623.67</td></tr><tr><td>44</td><td>0.0</td></tr><tr><td>45</td><td>118626.55</td></tr><tr><td>36</td><td>0.0</td></tr><tr><td>29</td><td>0.0</td></tr><tr><td>42</td><td>0.0</td></tr><tr><td>35</td><td>176273.95</td></tr><tr><td>41</td><td>102827.44</td></tr><tr><td>29</td><td>97086.4</td></tr><tr><td>22</td><td>0.0</td></tr><tr><td>34</td><td>0.0</td></tr><tr><td>40</td><td>0.0</td></tr><tr><td>44</td><td>0.0</td></tr><tr><td>31</td><td>82674.15</td></tr><tr><td>36</td><td>0.0</td></tr><tr><td>65</td><td>0.0</td></tr><tr><td>46</td><td>107073.27</td></tr><tr><td>32</td><td>88938.62</td></tr><tr><td>36</td><td>99806.85</td></tr><tr><td>33</td><td>15009 ...
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %%
spark.sql("SELECT Gender, COUNT(*) AS Count FROM credit_card GROUP BY Gender").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Gender</th><th>Count</th></tr></thead><tbody><tr><td>Female</td><td>4543</td></tr><tr><td>Male</td><td>5457</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.
