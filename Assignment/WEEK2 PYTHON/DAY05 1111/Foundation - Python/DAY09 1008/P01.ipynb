# %%
print("Om Saravana bava..")
# Out:
# Om Saravana bava..

# %%
# print("Hello World!") # Output Statement is print(); Strings needs to be within ""

# introduction = "Hello World!" #introduction is an identifier; i.e., variable
# print(introduction) #variables can be accessed in the file anywhere

# print(type(introduction)) #python is an dynamic language, so no type definition is required; type() is a built in function to result the datatype - literal type

# number1 = 76
# number2 =84.56
# print(type(number1))

# print(type(number2))

# # Single line of comment
# '''
# Multi line comment
# Line 2 of comment
# '''

# """
# Multi line comment
# Line 2 of comment
# Ctrl + / - shortcut to comment
# """

# '''
# identifiers
# literals
# functions
# keywords - built in or out of the box words or preserved words - print(), type(), for, if, str(), int()
# identifiers
# variable - start with small case
# Class - start with Capital case
# private - start with _
# magic function - start with __ - __init__

# '''

# %%
# # Python Case Sensitive
# # var1 or Var1 or VAR1 are different
# # var1 or var_1 strVar are correct
# # VarStr or Var1 or Var_1 - correct by not recommended
# # variable/function - snake_case - my_var1; get_details(), update_table()
# # constants - UPPERCASE - PI = 3.14; MULTIPLIER = 2; COMPANYNAME = "Hexaware"
# # Classes - CamelCase - CompanyInvoice

# name = "Hiran"
# _mobile = 8825410600
# email_id = "info@mjit.in"

# # 2ndName = "OS"
# # while = "True"

# print(name)

# name = "HRB"
# print(name)

# '''
# Numeric - it handles numbers - int, float, complex
# Sequence - it handles sequence of char, values - str, list, tuple
# Mapping - key value pairs - dictionary - dict
# Set - its kind of sequence - sets
# Boolean - True or False - bool
# '''
# int_1 = 10
# float_1 = 10.5
# comp_1 = 3+5j

# name = "Hiran"
# list_1 = [1,2,3,4,"Chennai"]
# tuple_1 = (1,2,3,4,"Chennai")

# dict_1 = {
#     "name": "Hiran",
#     "mobile": 8825410600
# }

# set_1 = {1,2,3,"Chennai"}

# is_active = True

# print(type(int_1))
# print(type(float_1))
# print(type(comp_1))
# print(type(name))
# print(type(list_1))
# print(type(tuple_1))
# print(type(dict_1))
# print(type(set_1))
# print(type(is_active))

# # output - print()
# # input - input()

# # name_2 = input("Enter your Name: ")
# name_2 = "HRB"
# print(name_2)

# # Output Formating
# # print(name)
# print("Entered Name is " + name_2) # Concatination Operator +; Only similar data type can be handled/concatenated or only strings
# print("Entered Name is", name_2) # multi value output; any datatype, any values can be concatenated, but it is little tricy to manage the output display
# print("Entered Name is {}".format(name_2)) # built in format function; similar to multi value but will look very simple for long output displays

# # print("The entered name is " + name_2 + "With an id of " + int_1 + ". also has an email address mapped as " + email_id ) # We cannot concate str and Int
# print("The entered name is", name_2, "With an id of", int_1, ". also has an email address mapped as", email_id )
# print("The entered name is {} With an id of {}. also has an email address mapped as {}".format(name_2,int_1, email_id) )

# # print("The entered name is " + name_2 + "With an id of " + int_1 + ". also has an email address mapped as " + email_id ) # We cannot concate str and Int
# # import sys
# # print("This is correct", file=sys.stderr)
# # sys.stderr.write("This is correct")

# %%
# '''
# Operators
# Arithmetic + - * / % **
# Comparision > < >= <= == !=
# Logical and or not
# Assignment = += -= *= /=
# Membership in, not in
# Identity is, is not
# '''

# int_1 = 10
# int_2 = 5

# print(int_1 + int_2)
# print(int_1 - int_2)
# print(int_1 * int_2)
# print(int_1 / int_2)
# print(int_1 % int_2)

# print(int_1 > int_2)
# print(int_1 < int_2)
# print(int_1 == int_2)

# bool_1 = True
# bool_2 = False

# print(bool_1 and bool_2)
# print(bool_1 or bool_2)
# print(not bool_1)

# print(int_1 > int_2 and not(int_1 == int_2))


# print('H' in name)
# print(1 in list_1)

# print( name is name_2)
# print(int_1 is not float_1)
